# %% [markdown]
# <a href="https://colab.research.google.com/github/vg2601/Karaoke-Cloud/blob/main/Start_Here.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title 1. Initialize System
import os
from google.colab import drive

# 1. Mount Drive
print("📂 Mounting Google Drive...")
drive.mount('/content/drive')

# 2. Define Repositories
MAIN_REPO = "https://github.com/YOUR_USERNAME/Karaoke-Cloud.git"
VIDEO_REPO = "https://github.com/YOUR_USERNAME/Karaoke-Video-Maker.git"

# 3. Install Universal Fonts & FFmpeg
print("⚙️ Installing Multimedia Tools & Fonts...")
# !apt-get install ffmpeg -y > /dev/null
# !apt-get install fonts-noto -y > /dev/null  # <--- CRITICAL FIX FOR BOXES
# !fc-cache -fv > /dev/null

print("✅ System Ready!")

# %%
# @title 2. Phase 1: Download & Separate (Main AI)
# @markdown This tool downloads songs, separates vocals, and fetches lyrics.
# @markdown **Select your mode below:**

MODE = "Command Line (Fast)" # @param ["Command Line (Fast)", "Visual Dashboard (Slow)"]

import os

# Clone/Update Main Repo
repo_name = "Karaoke-Cloud"
if not os.path.exists(repo_name):
    print(f"⬇️ Cloning {repo_name}...")
    # !git clone {MAIN_REPO}
else:
    print(f"🔄 Updating {repo_name}...")
    # %cd {repo_name}
    # !git pull

# %cd /content/{repo_name}

# Install AI
print("⚙️ Installing AI Engine (GPU)...")
# !pip install "audio-separator[gpu]" > /dev/null
# !pip install -r requirements.txt > /dev/null

if MODE == "Command Line (Fast)":
    # !python cli.py
else:
    print("⏳ Starting Dashboard...")
    # !pip install streamlit pyngrok > /dev/null
    # !npm install localtunnel -g > /dev/null
    # !curl ipv4.icanhazip.com
    # !streamlit run app.py &>/content/logs.txt &
    # !npx localtunnel --port 8501

# %%
# @title 3. Phase 2: Create Video Files (Optional)
# @markdown This tool scans your output folder and converts MP3+LRC into **MP4 Videos** for TV.

import os

# Clone/Update Video Repo
video_repo_name = "Karaoke-Video-Maker"
# %cd /content
if not os.path.exists(video_repo_name):
    print(f"⬇️ Cloning {video_repo_name}...")
    # !git clone {VIDEO_REPO}
else:
    print(f"🔄 Updating {video_repo_name}...")
    # %cd {video_repo_name}
    # !git pull

# %cd /content/{video_repo_name}

# Run the Video Maker
print("🚀 Starting Video Conversion...")
# !python video_maker.py
