# %% [markdown]
# <a href="https://colab.research.google.com/github/vg2601/Karaoke-Cloud/blob/main/Start_Here.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title 1. Initialize System (Click Play First)
# @markdown This sets up Google Drive, installs tools, and clones the Karaoke-Cloud repo.
import os
from google.colab import drive

# 1. Mount Drive
print("📂 Mounting Google Drive...")
drive.mount('/content/drive')

# 2. Clone Main Repository
REPO_URL = "https://github.com/vg2601/Karaoke-Cloud.git"
repo_name = "Karaoke-Cloud"

if not os.path.exists(repo_name):
    print(f"⬇️ Cloning {repo_name}...")
    # !git clone {REPO_URL}
else:
    print(f"🔄 Updating {repo_name}...")
    # %cd {repo_name}
    # !git pull

# %cd /content/{repo_name}

# 3. Install Tools & Fonts
print("⚙️ Installing Multimedia Tools & Fonts...")
# !apt-get install ffmpeg -y > /dev/null
# !apt-get install fonts-noto -y > /dev/null
# !fc-cache -fv > /dev/null
# !pip install "audio-separator[gpu]" > /dev/null
# !pip install -r requirements.txt > /dev/null

print("✅ System Ready!")

# %%
# @title 2. Phase 1: Download & Process
# @markdown Select **"Command Line"** for speed or **"Visual Dashboard"** for a UI.
# @markdown *Note: You will be asked if you want to generate TV Videos during this step.*

MODE = "Command Line (Fast)" # @param ["Command Line (Fast)", "Visual Dashboard (Slow)"]

if MODE == "Command Line (Fast)":
    # !python cli.py
else:
    print("⏳ Starting Dashboard...")
    # !pip install streamlit pyngrok > /dev/null
    # !npm install localtunnel -g > /dev/null
    # !curl ipv4.icanhazip.com
    # !streamlit run app.py &>/content/logs.txt &
    # !npx localtunnel --port 8501

# %%
# @title 3. Phase 2: Batch Video Processing (Optional)
# @markdown Run this ONLY if you skipped video generation in Step 2, or if you want to generate **Full Vocal Videos** (for listening).

print("🚀 Starting Batch Video Conversion...")
# !python video_maker.py
